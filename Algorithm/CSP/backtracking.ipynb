# %%
variables = [
    "Củ Chi",
    "Hóc Môn",
    "Quận 12",
    "Bình Tân",
    "Bình Chánh",
    "Gò Vấp",
    "Tân Bình",
    "Tân Phú",
    "Bình Thạnh",
    "Thủ Đức",
    "Phú Nhuận",
    "Quận 10",
    "Quận 11",
    "Quận 3",
    "Quận 1",
    "Quận 5",  
    "Quận 6",
    "Quận 4",
    "Quận 8",
    "Quận 7",
    "Nhà Bè",
    "Cần Giờ"
]

constrain = {
    "Củ Chi": ["Quận 12"],
    "Hóc Môn": ["Quận 12", "Bình Tân", "Bình Chánh", "Củ Chi"],
    "Quận 12": ["Gò Vấp", "Hóc Môn", "Tân Bình", "Tân Phú", "Bình Tân", "Thủ Đức", "Bình Thạnh"],
    "Bình Tân": ["Hóc Môn", "Quận 12", "Tân Phú", "Quận 6", "Quận 8", "Bình Chánh"],
    "Bình Chánh": ["Hóc Môn", "Bình Tân", "Quận 7", "Quận 8", "Nhà Bè"],
    "Gò Vấp": ["Quận 12", "Phú Nhuận", "Tân Bình", "Bình Thạnh", "Thủ Đức"],
    "Tân Bình": ["Quận 12", "Phú Nhuận", "Quận 11", "Quận 10", "Bình Tân", "Quận 3", "Quận 6"],
    "Tân Phú": ["Quận 12", "Bình Tân", "Quận 11", "Quận 6"],
    "Bình Thạnh": ["Quận 12", "Gò Vấp", "Phú Nhuận", "Quận 1", "Quận 4", "Thủ Đức"],
    "Thủ Đức": ["Quận 12", "Gò Vấp", "Phú Nhuận", "Bình Thạnh", "Quận 1", "Quận 4", "Quận 7"],
    "Phú Nhuận": ["Gò Vấp", "Tân Bình", "Quận 3", "Quận 1", "Thủ Đức", "Bình Thạnh"],
    "Quận 10": ["Quận 11", "Quận 5", "Tân Bình", "Quận 3", "Quận 4"],
    "Quận 11": ["Quận 10", "Tân Bình", "Tân Phú", "Quận 6", "Quận 4"],
    "Quận 3": ["Tân Bình", "Phú Nhuận", "Quận 5", "Quận 1", "Quận 10"],
    "Quận 1": ["Thủ Đức", "Bình Thạnh", "Phú Nhuận", "Quận 3", "Quận 5", "Quận 4"],
    "Quận 5": ["Quận 1", "Quận 3", "Quận 6", "Quận 8", "Quận 10", "Quận 11"],
    "Quận 6": ["Bình Tân", "Tân Bình", "Tân Phú", "Quận 11", "Quận 5", "Quận 8"],
    "Quận 4": ["Bình Thạnh", "Thủ Đức", "Quận 1", "Quận 7", "Quận 10", "Quận 11"],
    "Quận 8": ["Bình Tân", "Bình Chánh", "Quận 5", "Quận 6", "Quận 7"],
    "Quận 7": ["Quận 8", "Quận 4", "Thủ Đức", "Bình Chánh", "Nhà Bè"],
    "Nhà Bè": ["Cần Giờ", "Quận 7", "Bình Chánh"],
    "Cần Giờ": ["Nhà Bè"]
}

colors = ["Đỏ", "Vàng", "Xanh lá", "Xanh Dương"]
keys = list(constrain.keys())
result = {}

# %%
def is_valid(keys, color):
    global constrain, result
    
    
    for neighbor in constrain[keys]:
        if neighbor in result and result[neighbor] == color:
            return False
    
    return True

# %%
global keys, colors, result

def backtracking(index):
    if index == len(keys):
        return True
    
    area = keys[index]

    for color in colors:

        if is_valid(area, color):
            result[area] = color 
            print(f"Tô màu {color} cho {area}")
            
            if backtracking(index + 1):
                return True  

            print(f"Backtrack {area} (bỏ màu {color} vì không phù hợp ràng buộc)")
            del result[area] 

    return False

# %%
if backtracking(0):
    print("\nKết quả cuối cùng:")
    for area, color in result.items():
        print(area, ":", color)
else:
    print("Không thể tô màu")
# Out:
# To mau Đỏ cho Củ Chi
# To mau Vàng cho Hóc Môn
# To mau Đỏ cho Quận 12
# To mau Xanh lá cho Bình Tân
# To mau Đỏ cho Bình Chánh
# To mau Vàng cho Gò Vấp
# To mau Vàng cho Tân Bình
# To mau Vàng cho Tân Phú
# To mau Xanh lá cho Bình Thạnh
# To mau Xanh Dương cho Thủ Đức
# To mau Đỏ cho Phú Nhuận
# To mau Đỏ cho Quận 10
# To mau Xanh lá cho Quận 11
# To mau Xanh lá cho Quận 3
# To mau Vàng cho Quận 1
# To mau Xanh Dương cho Quận 5
# To mau Đỏ cho Quận 6
# Backtrack Quận 6 (bo mau Đỏ)
# Backtrack Quận 5 (bo mau Xanh Dương)
# Backtrack Quận 1 (bo mau Vàng)
# Backtrack Quận 3 (bo mau Xanh lá)
# To mau Xanh Dương cho Quận 3
# To mau Vàng cho Quận 1
# Backtrack Quận 1 (bo mau Vàng)
# Backtrack Quận 3 (bo mau Xanh Dương)
# Backtrack Quận 11 (bo mau Xanh lá)
# To mau Xanh Dương cho Quận 11
# To mau Xanh lá cho Quận 3
# To mau Vàng cho Quận 1
# Backtrack Quận 1 (bo mau Vàng)
# Backtrack Quận 3 (bo mau Xanh lá)
# To mau Xanh Dương cho Quận 3
# To mau Vàng cho Quận 1
# To mau Xanh lá cho Quận 5
# To mau Đỏ cho Quận 6
# Backtrack Quận 6 (bo mau Đỏ)
# Backtrack Quận 5 (bo mau Xanh lá)
# Backtrack Quận 1 (bo mau Vàng)
# Backtrack Quận 3 (bo mau Xanh Dương)
# Backtrack Quận 11 (bo mau Xanh Dương)
# Backtrack Quận 10 (bo mau Đỏ)
# To mau Xanh lá cho Quận 10
# To mau Đỏ cho Quận 11
# To mau Xanh Dương cho Quận 3
# To mau Vàng cho Quận 1
# Backtrack Quận 1 (bo mau Vàng)
# Backtrack Quận 3 (bo mau Xanh Dương)
# Backtrack Quận 11 (bo mau Đỏ)
# To mau Xanh Dương cho Quận 11
# To mau Xanh Dương cho Quận 3
# To mau Vàng cho Quận 1
# To mau Đỏ cho Quận 5
# Backtrack Quận 5 (bo mau Đỏ)
# Backtrack Quận 1 (bo mau Vàng)
# Backtrack Quận 3 (bo mau Xanh Dương)
# Backtrack Quận 11 (bo mau Xanh Dương)
# Backtrack Quận 10 (bo mau Xanh lá)
# To mau Xanh Dương cho Quận 10
# To mau Đỏ cho Quận 11
# To mau Xanh lá cho Quận 3
# To mau Vàng cho Quận 1
# Backtrack Quận 1 (bo mau Vàng)
# Backtrack Quận 3 (bo mau Xanh lá)
# Backtrack Quận 11 (bo mau Đỏ)
# To mau Xanh lá cho Quận 11
# To mau Xanh lá cho Quận 3
# To mau Vàng cho Quận 1
# To mau Đỏ cho Quận 5
# To mau Xanh Dương cho Quận 6
# To mau Đỏ cho Quận 4
# To mau Vàng cho Quận 8
# To mau Xanh lá cho Quận 7
# To mau Vàng cho Nhà Bè
# To mau Đỏ cho Cần Giờ
#
# Kết quả cuối cùng:
# Củ Chi : Đỏ
# Hóc Môn : Vàng
# Quận 12 : Đỏ
# Bình Tân : Xanh lá
# Bình Chánh : Đỏ
# Gò Vấp : Vàng
# Tân Bình : Vàng
# Tân Phú : Vàng
# Bình Thạnh : Xanh lá
# Thủ Đức : Xanh Dương
# Phú Nhuận : Đỏ
# Quận 10 : Xanh Dương
# Quận 11 : Xanh lá
# Quận 3 : Xanh lá
# Quận 1 : Vàng
# Quận 5 : Đỏ
# Quận 6 : Xanh Dương
# Quận 4 : Đỏ
# Quận 8 : Vàng
# Quận 7 : Xanh lá
# Nhà Bè : Vàng
# Cần Giờ : Đỏ
